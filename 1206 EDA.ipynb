# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
customer = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_cus_info.csv')

# %%
act = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_act_info.csv')

# %%
iem = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_iem_info.csv')

# %%
trd_kr = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_trd_kr.csv')

# %%
trd_oss = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_trd_oss.csv')

# %%
customer
# Out:
#                                                  cus_id  sex_dit_cd  cus_age  \
# 0     1eec7e43dd6ea34d6be7a9484459e4db1a2da44c5bf311...           2       20
# 1     7e50c268acce884b1a5b78c9b5645b517c4639413c6dc4...           2        0
# 2     36d3cd293c4b02a00103fa1ba33ffbee176173a55df75b...           1       70
# 3     96b6dea03dc71d9ddb1462e06fdba23def1ddc838debf7...           1       70
# 4     034eb5406bd021a9a88f046e33765efd5b3cd190b39538...           1       70
# ...                                                 ...         ...      ...
# 9995  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
# 9996  4d4e0c6c802058822d61622ae2b3e39471fa2a87152035...           2       35
# 9997  347190a59df83bbf2d87888915b95cd5b5c52fb781a45e...           2       35
# 9998  3ae218361d32511eec17e92b139f048ec2613ff6d56ac9...           1       35
# 9999  7bdea48b84cc322b3ef7d0b934d505afd467e11879571f...           1       35
#
#      zip_ctp_cd tco_cus_grd_cd ivs_icn_cd
# ...

# %%
customer.groupby(customer['cus_age']).count()
# Out:
#          cus_id  sex_dit_cd  zip_ctp_cd  tco_cus_grd_cd  ivs_icn_cd
# cus_age
# 0           212         212         212             212         212
# 20          348         348         348             348         348
# 25          906         906         906             906         906
# 30          957         957         957             957         957
# 35         1207        1207        1207            1207        1207
# 40         1302        1302        1302            1302        1302
# 45         1496        1496        1496            1496        1496
# 50         1272        1272        1272            1272        1272
# 55          987         987         987             987         987
# 60          647         647         647             647         647
# 65          312         312         312             312         312
# 70          354         354         354             354         354

# %%
customer.groupby(customer['tco_cus_grd_cd']).count()
# Out:
#                 cus_id  sex_dit_cd  cus_age  zip_ctp_cd  ivs_icn_cd
# tco_cus_grd_cd
# 01                 185         185      185         185         185
# 02                 447         447      447         447         447
# 03                1261        1261     1261        1261        1261
# 04                2182        2182     2182        2182        2182
# 05                2477        2477     2477        2477        2477
# 09                2810        2810     2810        2810        2810
# _                  638         638      638         638         638

# %%
act
# Out:
#                                                   act_id  \
# 0      8e1a987ebef2a3374ba558aeda4c7821de7808a11cfea1...
# 1      eb161b66263589c3f38efd2277cec2a9a81e1ffa0a5255...
# 2      01866857515304e9e1315e54863cc1108e1d46fff0d467...
# 3      63a58b0fee2fa4dc467c043fde465846b65705659497c5...
# 4      b563fb76d3d432d67198f194701ca67e895da4c2f24e8e...
# ...                                                  ...
# 23954  83a634e16d41723f45abb7171d2720b9ec31c0bb7614a5...
# 23955  fcc666cfa3def2e7023eaf1e28f39f0cb357d8cb9ec9f2...
# 23956  4bf846f46e7c0b8547a2e04caf6573976eb621156f3032...
# 23957  bdb499007eb246137859668816eebddde9bfeb3efaec8e...
# 23958  3e5168a7d5ec0efd23f240bd5d9530e4285ff9e661e81c...
#
#                                                   cus_id  act_opn_ym
# 0      892f41b5002a79c9c93992acf60682f5698372aea023bd...      197912
# 1      006ad32069efb2a8ce1a99542dfe41cb14e8e75685278a...      198702
# 2      1925ed2d8ed2cad53997f5b24722482137c4d1da4b555e...      199109
# ...

# %%
act.dtypes
# Out:
# act_id        object
# cus_id        object
# act_opn_ym     int64
# dtype: object

# %%
act['act_opn_ym'] = act.act_opn_ym.astype(str)

# %%
act['year'] = act['act_opn_ym'].str[0:4]

# %%
act['month'] = act.act_opn_ym.str.slice(-2)

# %%
act.head()
# Out:
#                                               act_id  \
# 0  8e1a987ebef2a3374ba558aeda4c7821de7808a11cfea1...
# 1  eb161b66263589c3f38efd2277cec2a9a81e1ffa0a5255...
# 2  01866857515304e9e1315e54863cc1108e1d46fff0d467...
# 3  63a58b0fee2fa4dc467c043fde465846b65705659497c5...
# 4  b563fb76d3d432d67198f194701ca67e895da4c2f24e8e...
#
#                                               cus_id act_opn_ym  year month
# 0  892f41b5002a79c9c93992acf60682f5698372aea023bd...     197912  1979    12
# 1  006ad32069efb2a8ce1a99542dfe41cb14e8e75685278a...     198702  1987    02
# 2  1925ed2d8ed2cad53997f5b24722482137c4d1da4b555e...     199109  1991    09
# 3  7829365dc463ed8275c8b92518d58b3c8d983f00f7bf87...     199401  1994    01
# 4  36e05dde058cf7531bd4001ed3b976ef9562a9ecd9f43d...     199404  1994    04

# %%
iem
# Out:
#             iem_cd                                         iem_eng_nm  \
# 0     A000060       Meritz Fire & Marine Insurance                ...
# 1     A000120       CJ LOGISTICS                                  ...
# 2     A000540       HeungkukFire&MarineInsurance                  ...
# 3     A00088K       HANWHA(3PB)                                   ...
# 4     A000950       Chonbang                                      ...
# ...            ...                                                ...
# 4680  US9839191015  Xilinx                                        ...
# 4681  US9884981013  Yum! Brands                                   ...
# 4682  VGG4095T1075  Greenland Tech                                ...
# 4683  VN000000SHB9  Sahabank                                      ...
# 4684  VN000000SPP2  Saplastic                                     ...
#
#                                              iem_krl_nm
# 0     메리츠화재해상보험보통주                                  ...
# ...

# %%
iem['type'] = iem.iem_krl_nm.str.slice(-2,-1)

# %%
iem.head()
# Out:
#          iem_cd                                         iem_eng_nm  \
# 0  A000060       Meritz Fire & Marine Insurance                ...
# 1  A000120       CJ LOGISTICS                                  ...
# 2  A000540       HeungkukFire&MarineInsurance                  ...
# 3  A00088K       HANWHA(3PB)                                   ...
# 4  A000950       Chonbang                                      ...
#
#                                           iem_krl_nm type
# 0  메리츠화재해상보험보통주                                  ...
# 1  씨제이대한통운보통주                                    ...
# 2  흥국화재해상보험보통주                                   ...
# 3  한화3우선주(신형)                                    ...
# 4  전방보통주                                         ...

# %%
trd_kr
# Out:
#                                                     act_id    orr_dt  orr_ord  \
# 0        6caf4de40251d37cbba310f0c6dd0ed8f4c7ca4ccfa675...  20190102        1
# 1        6caf4de40251d37cbba310f0c6dd0ed8f4c7ca4ccfa675...  20190102        2
# 2        effb34815e1b7efb34beb550f604ede8ac71a5a71edb30...  20190102        1
# 3        fea6c038cb7236a02d1e779262698a36219b4c9b527ab1...  20190102        1
# 4        fea6c038cb7236a02d1e779262698a36219b4c9b527ab1...  20190102        2
# ...                                                    ...       ...      ...
# 3312659  a96172625957ac18f6debba0c3283f1aa4608c1d19a404...  20200630        2
# 3312660  a96172625957ac18f6debba0c3283f1aa4608c1d19a404...  20200630        3
# 3312661  c8d469612160df7251dd5d434ca25b0b8e2f40ace9a37f...  20200630        1
# 3312662  1a046249ad088f30dae8038eb95d51427f10228677d4fb...  20200630        1
# 3312663  1a046249ad088f30dae8038eb95d51427f10228677d4fb...  20200630        2
#
# ...

# %%
trd_kr.info
# Out:
# <bound method DataFrame.info of                                                     act_id    orr_dt  orr_ord  \
# 0        6caf4de40251d37cbba310f0c6dd0ed8f4c7ca4ccfa675...  20190102        1
# 1        6caf4de40251d37cbba310f0c6dd0ed8f4c7ca4ccfa675...  20190102        2
# 2        effb34815e1b7efb34beb550f604ede8ac71a5a71edb30...  20190102        1
# 3        fea6c038cb7236a02d1e779262698a36219b4c9b527ab1...  20190102        1
# 4        fea6c038cb7236a02d1e779262698a36219b4c9b527ab1...  20190102        2
# ...                                                    ...       ...      ...
# 3312659  a96172625957ac18f6debba0c3283f1aa4608c1d19a404...  20200630        2
# 3312660  a96172625957ac18f6debba0c3283f1aa4608c1d19a404...  20200630        3
# 3312661  c8d469612160df7251dd5d434ca25b0b8e2f40ace9a37f...  20200630        1
# 3312662  1a046249ad088f30dae8038eb95d51427f10228677d4fb...  20200630        1
# 3312663  1a046249ad088f30dae8038eb95d51427f10228677d4fb...  20200630        2
#
# ...

# %%
trd_oss
# Out:
#                                                   act_id    orr_dt  orr_ord  \
# 0      12c2bf5b4929fa3cb8b8aa7b45c0d000f7e3b868621b5b...  20190102        1
# 1      f51b1d8b13186e30aee7a407e235eb87b6b84ed85ca7a4...  20190102        1
# 2      f51b1d8b13186e30aee7a407e235eb87b6b84ed85ca7a4...  20190102        2
# 3      37bc7b62e55f0cf8402a1f86dc8d09b09a3028bb13afa6...  20190103        1
# 4      e340482168a2154b323ec2b9a0d003d840590ddafb0e2b...  20190103        1
# ...                                                  ...       ...      ...
# 29296  3f17959c32c50ee64012a5344fb3e6b1ba038963b89ca8...  20200630        1
# 29297  3f17959c32c50ee64012a5344fb3e6b1ba038963b89ca8...  20200630        2
# 29298  3f17959c32c50ee64012a5344fb3e6b1ba038963b89ca8...  20200630        3
# 29299  3f17959c32c50ee64012a5344fb3e6b1ba038963b89ca8...  20200630        4
# 29300  df6a314d9ef943cdb66a308a37362c492d2b8ecdfcec82...  20200630        1
#
# ...

# %%
trd_oss['cns_qty'].groupby([trd_oss['orr_dt'],trd_oss['cur_cd']]).mean()
# Out:
# orr_dt    cur_cd
# 20190102  CNY        100.000000
#           HKD        600.000000
#           USD          6.000000
# 20190103  USD          4.500000
#           VND        230.000000
#                        ...
# 20200630  EUR         15.000000
#           HKD       2000.000000
#           IDR       1900.000000
#           JPY        800.000000
#           USD         56.930348
# Name: cns_qty, Length: 868, dtype: float64

# %%
# !pip install -U pandas_profiling
import pandas_profiling
# Out:
# Requirement already up-to-date: pandas_profiling in c:\users\krist\anaconda3\lib\site-packages (2.9.0)
# ...

# %%
import pandas_profiling as pp

# %%
ppr = pp.ProfileReport(customer)

# %%
ppr.to_widgets()

# %%
ppr=pp.ProfileReport(trd_oss)

# %%
ppr.to_widgets()
