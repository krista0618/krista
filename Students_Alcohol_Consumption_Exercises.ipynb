# %% [markdown]
# <a href="https://colab.research.google.com/github/krista0618/krista/blob/krista/Students_Alcohol_Consumption_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %%
pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv')

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df[['school','sex','address','famsize','Pstatus','Medu','Fedu','Mjob','Fjob','reason', 'guardian']]
# Out:
#     school sex address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F       U     GT3       A     4     4   at_home   teacher
# 1       GP   F       U     GT3       T     1     1   at_home     other
# 2       GP   F       U     LE3       T     1     1   at_home     other
# 3       GP   F       U     GT3       T     4     2    health  services
# 4       GP   F       U     GT3       T     3     3     other     other
# 5       GP   M       U     LE3       T     4     3  services     other
# 6       GP   M       U     LE3       T     2     2     other     other
# 7       GP   F       U     GT3       A     4     4     other   teacher
# 8       GP   M       U     LE3       A     3     2  services     other
# 9       GP   M       U     GT3       T     3     4     other     other
# 10      GP   F       U     GT3       T     4     4   teacher    health
# 11      GP   F       U     GT3       T     2     1  services     other
# ...

# %% [markdown]
# ### Step 5. Create a lambda function that capitalize strings.

# %%
Cap = lambda x:x.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df['Mjob'].apply(Cap)
df['Fjob'].apply(Cap)
# Out:
# 0       Teacher
# 1         Other
# 2         Other
# 3      Services
# 4         Other
# 5         Other
# 6         Other
# 7       Teacher
# 8         Other
# 9         Other
# 10       Health
# 11        Other
# 12     Services
# 13        Other
# 14        Other
# 15        Other
# 16     Services
# 17        Other
# 18     Services
# 19        Other
# 20        Other
# 21       Health
# 22        Other
# 23        Other
# 24       Health
# 25     Services
# 26        Other
# 27     Services
# 28        Other
# 29      Teacher
#          ...
# 365       Other
# 366    Services
# 367    Services
# 368    Services
# 369     Teacher
# 370    Services
# 371    Services
# 372     At_home
# 373       Other
# 374       Other
# 375       Other
# 376       Other
# 377    Services
# 378       Other
# 379       Other
# 380     Teacher
# 381       Other
# 382    Services
# 383    Services
# 384       Other
# 385       Other
# 386     At_home
# 387       Other
# 388    Services
# ...

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
df['Mjob'] = df['Mjob'].apply(Cap)
df['Fjob'] = df['Fjob'].apply(Cap)
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  Services  Services
# 391     MS   M   17       U     LE3       T     3     1  Services  Services
# 392     MS   M   21       R     GT3       T     1     1     Other     Other
# 393     MS   M   18       R     LE3       T     3     2  Services     Other
# 394     MS   M   19       U     LE3       T     1     1     Other   At_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majority(x):
  if x>17:
    return True
  else:
    return False

df['legal_drinker'] = df['age'].apply(majority)

# %%
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-39-d6b63e9c2cfc> in <module>()
# ----> 1 df['legal_drinker'] = df['age'].apply(majority)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: majority() takes no arguments (1 given)

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
def multiple10(x):
  if type(x) == int:
    return x*10
    return x 
df.applymap(multiple10)
# Out:
#     school   sex  age address famsize Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0     None  None  180    None    None    None    40    40  None  None  ...
# 1     None  None  170    None    None    None    10    10  None  None  ...
# 2     None  None  150    None    None    None    10    10  None  None  ...
# 3     None  None  150    None    None    None    40    20  None  None  ...
# 4     None  None  160    None    None    None    30    30  None  None  ...
# 5     None  None  160    None    None    None    40    30  None  None  ...
# 6     None  None  160    None    None    None    20    20  None  None  ...
# 7     None  None  170    None    None    None    40    40  None  None  ...
# 8     None  None  150    None    None    None    30    20  None  None  ...
# 9     None  None  150    None    None    None    30    40  None  None  ...
# 10    None  None  150    None    None    None    40    40  None  None  ...
# ...
