# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
customer = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_cus_info.csv')

# %%
act = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_act_info.csv')

# %%
iem = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_iem_info.csv')

# %%
trd_kr = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_trd_kr.csv')

# %%
trd_oss = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_trd_oss.csv')

# %%
trd_kr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3312664 entries, 0 to 3312663
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   act_id          object
#  1   orr_dt          int64
#  2   orr_ord         int64
#  3   orr_rtn_hur     int64
#  4   lst_cns_hur     int64
#  5   iem_cd          object
#  6   sby_dit_cd      int64
#  7   cns_qty         float64
#  8   orr_pr          float64
#  9   orr_mdi_dit_cd  int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 227.5+ MB

# %%
customer
# Out:
#                                                  cus_id  sex_dit_cd  cus_age  \
# 0     1eec7e43dd6ea34d6be7a9484459e4db1a2da44c5bf311...           2       20
# 1     7e50c268acce884b1a5b78c9b5645b517c4639413c6dc4...           2        0
# 2     36d3cd293c4b02a00103fa1ba33ffbee176173a55df75b...           1       70
# 3     96b6dea03dc71d9ddb1462e06fdba23def1ddc838debf7...           1       70
# 4     034eb5406bd021a9a88f046e33765efd5b3cd190b39538...           1       70
# ...                                                 ...         ...      ...
# 9995  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
# 9996  4d4e0c6c802058822d61622ae2b3e39471fa2a87152035...           2       35
# 9997  347190a59df83bbf2d87888915b95cd5b5c52fb781a45e...           2       35
# 9998  3ae218361d32511eec17e92b139f048ec2613ff6d56ac9...           1       35
# 9999  7bdea48b84cc322b3ef7d0b934d505afd467e11879571f...           1       35
#
#      zip_ctp_cd tco_cus_grd_cd ivs_icn_cd
# ...

# %%
table = customer.groupby([customer['ivs_icn_cd'],customer['cus_age']]).count()

# %%
table.sort_index(ascending = False).head(60)
# Out:
#                     cus_id  sex_dit_cd  zip_ctp_cd  tco_cus_grd_cd
# ivs_icn_cd cus_age
# 09         50            1           1           1               1
#            35            1           1           1               1
# 05         70           16          16          16              16
#            65           20          20          20              20
#            60           48          48          48              48
#            55           89          89          89              89
#            50          117         117         117             117
#            45          148         148         148             148
#            40          165         165         165             165
#            35          162         162         162             162
#            30          102         102         102             102
#            25           35          35          35              35
#            20            4           4           4               4
# ...

# %% [raw]
# 01: 안정형 / 02: 안정추구형 / 03: 위험중립형 / 04: 적극투자형 / 05: 공격투자형 / 09: 전문투자자형 / -: 정보제공미동의

# %%
Z = customer[(customer['cus_age']>=0) & (customer['cus_age']<30)]

# %%
Z_table = Z.groupby([Z['ivs_icn_cd'],Z['cus_age']]).count()

# %%
Z_table.sort_index(ascending = False).head(70)
# Out:
#                     cus_id  sex_dit_cd  zip_ctp_cd  tco_cus_grd_cd
# ivs_icn_cd cus_age
# 05         25           35          35          35              35
#            20            4           4           4               4
#            0            28          28          28              28
# 04         25          115         115         115             115
#            20           32          32          32              32
#            0            39          39          39              39
# 03         25          152         152         152             152
#            20           68          68          68              68
#            0            29          29          29              29
# 02         25          202         202         202             202
#            20           78          78          78              78
#            0            16          16          16              16
# 01         25           57          57          57              57
# ...

# %%
Y = customer[(customer['cus_age']>=30) & (customer['cus_age']<45)]

# %%
Y
# Out:
#                                                  cus_id  sex_dit_cd  cus_age  \
# 1146  b269192b83b41bdd494d9359c2b09bee8d2590fd1a9dab...           1       40
# 1147  4f1f253d67e417b7b6fd84ad7cbb1673b26c4ef3e46001...           1       40
# 1148  3812991826c4fa66bf78bc62595d173d86823170d58aa1...           1       40
# 1149  30106fadfa46d996beab5bed097f63d22c43363b28dc79...           1       40
# 1150  2d9ff010ae278c4106ab76eb1f592ef47fb955463b3568...           1       40
# ...                                                 ...         ...      ...
# 9995  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
# 9996  4d4e0c6c802058822d61622ae2b3e39471fa2a87152035...           2       35
# 9997  347190a59df83bbf2d87888915b95cd5b5c52fb781a45e...           2       35
# 9998  3ae218361d32511eec17e92b139f048ec2613ff6d56ac9...           1       35
# 9999  7bdea48b84cc322b3ef7d0b934d505afd467e11879571f...           1       35
#
#      zip_ctp_cd tco_cus_grd_cd ivs_icn_cd
# ...

# %%
Y_table = Y.groupby([Y['ivs_icn_cd'],Y['cus_age']]).count()

# %%
Y_table
# Out:
#                     cus_id  sex_dit_cd  zip_ctp_cd  tco_cus_grd_cd
# ivs_icn_cd cus_age
# -          30          333         333         333             333
#            35          470         470         470             470
#            40          589         589         589             589
# 00         30           15          15          15              15
#            35           27          27          27              27
#            40           26          26          26              26
# 01         30            8           8           8               8
#            35            1           1           1               1
#            40            9           9           9               9
# 02         30          137         137         137             137
#            35          120         120         120             120
#            40          102         102         102             102
# 03         30          167         167         167             167
# ...

# %%
Y_table.sort_index(ascending = False).head(70)
# Out:
#                     cus_id  sex_dit_cd  zip_ctp_cd  tco_cus_grd_cd
# ivs_icn_cd cus_age
# 09         35            1           1           1               1
# 05         40          165         165         165             165
#            35          162         162         162             162
#            30          102         102         102             102
# 04         40          240         240         240             240
#            35          234         234         234             234
#            30          195         195         195             195
# 03         40          171         171         171             171
#            35          192         192         192             192
#            30          167         167         167             167
# 02         40          102         102         102             102
#            35          120         120         120             120
#            30          137         137         137             137
# ...

# %%
X = customer[(customer['cus_age']>=45) & (customer['cus_age']<60)]
X_table = X.groupby([X['ivs_icn_cd'],X['cus_age']]).count()
X_table.sort_index(ascending = False).head(70)
# Out:
#                     cus_id  sex_dit_cd  zip_ctp_cd  tco_cus_grd_cd
# ivs_icn_cd cus_age
# 09         50            1           1           1               1
# 05         55           89          89          89              89
#            50          117         117         117             117
#            45          148         148         148             148
# 04         55          206         206         206             206
#            50          259         259         259             259
#            45          287         287         287             287
# 03         55          140         140         140             140
#            50          175         175         175             175
#            45          189         189         189             189
# 02         55           66          66          66              66
#            50          109         109         109             109
#            45          132         132         132             132
# ...

# %%
Z_table.plot.bar()

# %%
Y_table.plot.bar()

# %%
X_table.plot.bar()

# %%
act
# Out:
#                                                   act_id  \
# 0      8e1a987ebef2a3374ba558aeda4c7821de7808a11cfea1...
# 1      eb161b66263589c3f38efd2277cec2a9a81e1ffa0a5255...
# 2      01866857515304e9e1315e54863cc1108e1d46fff0d467...
# 3      63a58b0fee2fa4dc467c043fde465846b65705659497c5...
# 4      b563fb76d3d432d67198f194701ca67e895da4c2f24e8e...
# ...                                                  ...
# 23954  83a634e16d41723f45abb7171d2720b9ec31c0bb7614a5...
# 23955  fcc666cfa3def2e7023eaf1e28f39f0cb357d8cb9ec9f2...
# 23956  4bf846f46e7c0b8547a2e04caf6573976eb621156f3032...
# 23957  bdb499007eb246137859668816eebddde9bfeb3efaec8e...
# 23958  3e5168a7d5ec0efd23f240bd5d9530e4285ff9e661e81c...
#
#                                                   cus_id  act_opn_ym
# 0      892f41b5002a79c9c93992acf60682f5698372aea023bd...      197912
# 1      006ad32069efb2a8ce1a99542dfe41cb14e8e75685278a...      198702
# 2      1925ed2d8ed2cad53997f5b24722482137c4d1da4b555e...      199109
# ...

# %%
trd_kr
# Out:
#                                                     act_id    orr_dt  orr_ord  \
# 0        6caf4de40251d37cbba310f0c6dd0ed8f4c7ca4ccfa675...  20190102        1
# 1        6caf4de40251d37cbba310f0c6dd0ed8f4c7ca4ccfa675...  20190102        2
# 2        effb34815e1b7efb34beb550f604ede8ac71a5a71edb30...  20190102        1
# 3        fea6c038cb7236a02d1e779262698a36219b4c9b527ab1...  20190102        1
# 4        fea6c038cb7236a02d1e779262698a36219b4c9b527ab1...  20190102        2
# ...                                                    ...       ...      ...
# 3312659  a96172625957ac18f6debba0c3283f1aa4608c1d19a404...  20200630        2
# 3312660  a96172625957ac18f6debba0c3283f1aa4608c1d19a404...  20200630        3
# 3312661  c8d469612160df7251dd5d434ca25b0b8e2f40ace9a37f...  20200630        1
# 3312662  1a046249ad088f30dae8038eb95d51427f10228677d4fb...  20200630        1
# 3312663  1a046249ad088f30dae8038eb95d51427f10228677d4fb...  20200630        2
#
# ...

# %%
trd_kr.sort_values(by='cns_qty',ascending = False)
# Out:
#                                                     act_id    orr_dt  orr_ord  \
# 1441028  8a7c609ccc5f931484b4e211e6f679799f5d08d3681a73...  20200408       21
# 1441035  8a7c609ccc5f931484b4e211e6f679799f5d08d3681a73...  20200408       28
# 1441036  8a7c609ccc5f931484b4e211e6f679799f5d08d3681a73...  20200408       29
# 1553407  8a7c609ccc5f931484b4e211e6f679799f5d08d3681a73...  20200625      717
# 1553405  8a7c609ccc5f931484b4e211e6f679799f5d08d3681a73...  20200625      715
# ...                                                    ...       ...      ...
# 2144223  2369177fe115c6f48136f308d0ea3ad1fe2dd64525c3c1...  20200417       10
# 2144232  004b2ea0a6754393b914fb9f39c64ef870709da0b36c51...  20200417        1
# 2144233  004b2ea0a6754393b914fb9f39c64ef870709da0b36c51...  20200417        2
# 2144234  004b2ea0a6754393b914fb9f39c64ef870709da0b36c51...  20200417        3
# 828580   cbce6477da62e95ace2199a28bf3c42c2aaadfdbaa94ef...  20191018       26
#
# ...

# %%
trd_kr['act_id'].value_counts()
# Out:
# bcafbbacb623d49ce60a2fb048ec552796061bfa64a14e4a00bd1a1b19d813ab    79361
# 861fade671d93fbaacdfeb2c28a766b445c11e1444aa46031d4c3c6374354250    76870
# c5b8848f414ec920dbab0cebed9c07fbf2337848eb0fec2fc77c84b3a1854b5f    45418
# 9ec853297748da4129aeb41510d63d141c64c9c4726461152aa0783aedfa4c3f    31509
# b68092f195cb2d1dddb424f8268ac03e9c9f68db81d2ed550e786466792de115    24790
#                                                                     ...
# b175cd06037860fe64d39e75c3fa607a4e4e75553a045bf240fbbc0ca798ce53        1
# 689f20d48548c20cc591ba9cb8ff13414a67586f8e4e5fd778e8d38b06ce235a        1
# 5dc20cb69ae97cfe702624afe11548840c65b9a1aa74ecdb20c3965754d589ea        1
# 8914e5c8034be0e242c489facb47a719b20f69bae679de0e56310157efda9a22        1
# 37280ebfed44e395bf3fc8e26c7a48bb6c7b9e356553f19758f2b05b8bcbd198        1
# Name: act_id, Length: 10997, dtype: int64

# %%
trd_kr_table =trd_kr.groupby(trd_kr['act_id']).sum()
trd_kr_table
# Out:
#                                                         orr_dt  orr_ord  \
# act_id
# 0008f20f69bfedf80e50f89059af9c7b6da2767d022ebc7...   303008841       20
# 000beb3372f69a4c5048481c8f8670cce530bcffd810bfb...   686816388       61
# 000eb41ce4d0ad012c12b370642978ec645812e02266483...  3777501062      732
# 000f15cb9f43c17bc550cbabe7cac9f2d733e96f696e9f6...    80801443        4
# 00101083c78a6f6ea789cd67db3800deed69e7631514676...    20200604        1
# ...                                                        ...      ...
# ffc4158488253fb49f23c4bfbe3e6b7ca752c3d237bd86b...  1231811169       74
# ffc61ceafe55c436846174865c747aa9c106b44ff77e672...  4100677059      521
# ffda48bb40b6a8e40fc87549b9bddfc220c94b5397a303d...  1090292027      113
# ffed8bd860b8d18bff1f75b1f75dd3f62f9e046c8c6b683...    20200622        1
# fffb8aa6111bcd36165d237d8a0d63ad7616bbaff9ec5f1...  1090564350      149
#
#                                                     orr_rtn_hur  lst_cns_hur  \
# act_id
# ...

# %%
trd_oss
# Out:
#                                                   act_id    orr_dt  orr_ord  \
# 0      12c2bf5b4929fa3cb8b8aa7b45c0d000f7e3b868621b5b...  20190102        1
# 1      f51b1d8b13186e30aee7a407e235eb87b6b84ed85ca7a4...  20190102        1
# 2      f51b1d8b13186e30aee7a407e235eb87b6b84ed85ca7a4...  20190102        2
# 3      37bc7b62e55f0cf8402a1f86dc8d09b09a3028bb13afa6...  20190103        1
# 4      e340482168a2154b323ec2b9a0d003d840590ddafb0e2b...  20190103        1
# ...                                                  ...       ...      ...
# 29296  3f17959c32c50ee64012a5344fb3e6b1ba038963b89ca8...  20200630        1
# 29297  3f17959c32c50ee64012a5344fb3e6b1ba038963b89ca8...  20200630        2
# 29298  3f17959c32c50ee64012a5344fb3e6b1ba038963b89ca8...  20200630        3
# 29299  3f17959c32c50ee64012a5344fb3e6b1ba038963b89ca8...  20200630        4
# 29300  df6a314d9ef943cdb66a308a37362c492d2b8ecdfcec82...  20200630        1
#
# ...

# %%
trd_oss_table = trd_oss.groupby(trd_oss['act_id']).sum()
trd_oss_table
# Out:
#                                                         orr_dt  orr_ord  \
# act_id
# 000eb41ce4d0ad012c12b370642978ec645812e02266483...    40401246        3
# 00649c44a4f3149035ab8fa8b0df7c29f69ec70d77fbe9f...   787823667       78
# 006896b537767cd893f18f54ef8a60665592fc069e31391...   767620721      140
# 00e864e333fa507736d120dcfd770e216b914b31f8642b8...   202004845       15
# 00fb30f4b04caae456a222ead4da3a9f2ac31473bed69e8...   545411720       61
# ...                                                        ...      ...
# fef5ac5a6dfad3f344075353ffa43b45b7c7826a45c0680...  1231936200      129
# ff5c422b6b47267dc5b7585135a00da04c728fc32f75c07...   848419995       91
# ff607ee6d81379e30b6bed44db6ccd634f2d5e406f4ea1e...    60601831        4
# ff85c967c434b28730b755da5037159ce376f8766f20b1e...  1191824327      490
# ff86f59aa3c130c0f5f2c97e4d14fb6622455b1f61884c4...   101002171        7
#
#                                                     orr_rtn_hur  lst_cns_hur  \
# act_id
# ...

# %%
trade = pd.merge(trd_kr_table, trd_oss_table, on = 'act_id')

# %%
trade2 = pd.merge(act, trade, on = 'act_id')

# %%
trade3 = pd.merge(customer, trade2, on = 'cus_id')
trade3
# Out:
#                                                 cus_id  sex_dit_cd  cus_age  \
# 0    2582f8ba6a49867ee265a2382d9a07cd4bee71d9e95c7a...           1       70
# 1    ef07ba51d74bd9643975549098f0ca37bafc93f9496528...           2       70
# 2    69c058f71b959ab4529f8b7d455d36bc7605a87cb95036...           2       70
# 3    5b4bd1d5fa738513eb1697b4687b0cc29e1eb275e2cbbf...           1       65
# 4    6cdc07565be85a63c4e2031d61fc34445e03b113e83642...           1       65
# ..                                                 ...         ...      ...
# 673  24653394d720670b49b1146b2793481bdca7aa7a84d11c...           1       55
# 674  35a141312260b8c75681c4523fe665b45c8ae85b82fe3b...           1       55
# 675  d7ec1ffebdbfa829cf7f4f982bcb90b29d112d34ea85aa...           1       40
# 676  7a75ef6ed9c903c6d18fa8f9eaf6767b06cbb434639652...           1       40
# 677  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
#
#     zip_ctp_cd tco_cus_grd_cd ivs_icn_cd  \
# ...

# %%
trade3.groupby("cus_age").mean()
# Out:
#          sex_dit_cd     act_opn_ym      orr_dt_x    orr_ord_x  orr_rtn_hur_x  \
# cus_age
# 0          1.363636  201877.681818  9.510701e+08   226.863636     539.409091
# 20         1.245614  201958.824561  2.415797e+09  1492.824561    1352.508772
# 25         1.298507  201885.917910  4.739757e+09  2377.223881    2562.947761
# 30         1.208696  201833.139130  4.504745e+09  2339.286957    2464.182609
# 35         1.298969  201732.010309  3.878993e+09  2654.927835    2086.051546
# 40         1.223684  201782.894737  3.373995e+09  1099.671053    1846.223684
# 45         1.302632  201586.723684  2.803779e+09  1057.381579    1540.223684
# 50         1.446809  201275.702128  8.791053e+09  7971.106383    5003.723404
# 55         1.312500  201514.968750  6.207031e+09  2282.437500    3321.875000
# 60         1.333333  201306.083333  9.273363e+08   207.333333     492.000000
# 65         1.000000  201145.200000  4.620905e+09   841.000000    2657.800000
# ...
