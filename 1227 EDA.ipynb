# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cus_info = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_cus_info.csv')

# %%
act_info2 = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_act_info.csv')

# %%
iem_info = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_iem_info.csv')

# %%
trd_kr_info = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_trd_kr.csv')

# %%
trd_oss_info = pd.read_csv('C:/Users/krist/Downloads/리그2/리그2/2_trd_oss.csv')

# %%
table = customer.groupby([customer['ivs_icn_cd'],customer['cus_age']]).count()

# %%
table.sort_index(ascending = False).head(60)
# Out:
#                     cus_id  sex_dit_cd  zip_ctp_cd  tco_cus_grd_cd
# ivs_icn_cd cus_age
# 09         50            1           1           1               1
#            35            1           1           1               1
# 05         70           16          16          16              16
#            65           20          20          20              20
#            60           48          48          48              48
#            55           89          89          89              89
#            50          117         117         117             117
#            45          148         148         148             148
#            40          165         165         165             165
#            35          162         162         162             162
#            30          102         102         102             102
#            25           35          35          35              35
#            20            4           4           4               4
# ...

# %% [raw]
# 01: 안정형 / 02: 안정추구형 / 03: 위험중립형 / 04: 적극투자형 / 05: 공격투자형 / 09: 전문투자자형 / -: 정보제공미동의

# %%
Z = customer_info[(customer_info['cus_age']>=20) & (customer_info['cus_age']<30)]

# %%
Z_table = Z.groupby([Z['ivs_icn_cd'],Z['cus_age']]).count()

# %%
Z_table.sort_index(ascending = False).head(70)
# Out:
#                     cus_id  sex_dit_cd  zip_ctp_cd  tco_cus_grd_cd
# ivs_icn_cd cus_age
# 05         25           35          35          35              35
#            20            4           4           4               4
# 04         25          115         115         115             115
#            20           32          32          32              32
# 03         25          152         152         152             152
#            20           68          68          68              68
# 02         25          202         202         202             202
#            20           78          78          78              78
# 01         25           57          57          57              57
#            20           40          40          40              40
# 00         25           10          10          10              10
#            20            8           8           8               8
# -          25          335         335         335             335
# ...

# %%
Y = customer_info[(customer_info['cus_age']>=30) & (customer_info['cus_age']<40)]

# %%
Y_table = Y.groupby([Y['ivs_icn_cd'],Y['cus_age']]).count()

# %%
Y_table
# Out:
#                     cus_id  sex_dit_cd  zip_ctp_cd  tco_cus_grd_cd
# ivs_icn_cd cus_age
# -          30          333         333         333             333
#            35          470         470         470             470
#            40          589         589         589             589
# 00         30           15          15          15              15
#            35           27          27          27              27
#            40           26          26          26              26
# 01         30            8           8           8               8
#            35            1           1           1               1
#            40            9           9           9               9
# 02         30          137         137         137             137
#            35          120         120         120             120
#            40          102         102         102             102
# 03         30          167         167         167             167
# ...

# %%
Y_table.sort_index(ascending = False).head(70)
# Out:
#                     cus_id  sex_dit_cd  zip_ctp_cd  tco_cus_grd_cd
# ivs_icn_cd cus_age
# 09         35            1           1           1               1
# 05         35          162         162         162             162
#            30          102         102         102             102
# 04         35          234         234         234             234
#            30          195         195         195             195
# 03         35          192         192         192             192
#            30          167         167         167             167
# 02         35          120         120         120             120
#            30          137         137         137             137
# 01         35            1           1           1               1
#            30            8           8           8               8
# 00         35           27          27          27              27
#            30           15          15          15              15
# ...

# %%
Z_table.plot.bar()

# %%
Y_table.plot.bar()

# %%
trd_kr_info
# Out:
#                                                     act_id    orr_dt  orr_ord  \
# 0        6caf4de40251d37cbba310f0c6dd0ed8f4c7ca4ccfa675...  20190102        1
# 1        6caf4de40251d37cbba310f0c6dd0ed8f4c7ca4ccfa675...  20190102        2
# 2        effb34815e1b7efb34beb550f604ede8ac71a5a71edb30...  20190102        1
# 3        fea6c038cb7236a02d1e779262698a36219b4c9b527ab1...  20190102        1
# 4        fea6c038cb7236a02d1e779262698a36219b4c9b527ab1...  20190102        2
# ...                                                    ...       ...      ...
# 3312659  a96172625957ac18f6debba0c3283f1aa4608c1d19a404...  20200630        2
# 3312660  a96172625957ac18f6debba0c3283f1aa4608c1d19a404...  20200630        3
# 3312661  c8d469612160df7251dd5d434ca25b0b8e2f40ace9a37f...  20200630        1
# 3312662  1a046249ad088f30dae8038eb95d51427f10228677d4fb...  20200630        1
# 3312663  1a046249ad088f30dae8038eb95d51427f10228677d4fb...  20200630        2
#
# ...

# %%
trd_kr_info.sort_values(by='cns_qty',ascending = False)
# Out:
#                                                     act_id    orr_dt  orr_ord  \
# 1441028  8a7c609ccc5f931484b4e211e6f679799f5d08d3681a73...  20200408       21
# 1441035  8a7c609ccc5f931484b4e211e6f679799f5d08d3681a73...  20200408       28
# 1441036  8a7c609ccc5f931484b4e211e6f679799f5d08d3681a73...  20200408       29
# 1553407  8a7c609ccc5f931484b4e211e6f679799f5d08d3681a73...  20200625      717
# 1553405  8a7c609ccc5f931484b4e211e6f679799f5d08d3681a73...  20200625      715
# ...                                                    ...       ...      ...
# 2144223  2369177fe115c6f48136f308d0ea3ad1fe2dd64525c3c1...  20200417       10
# 2144232  004b2ea0a6754393b914fb9f39c64ef870709da0b36c51...  20200417        1
# 2144233  004b2ea0a6754393b914fb9f39c64ef870709da0b36c51...  20200417        2
# 2144234  004b2ea0a6754393b914fb9f39c64ef870709da0b36c51...  20200417        3
# 828580   cbce6477da62e95ace2199a28bf3c42c2aaadfdbaa94ef...  20191018       26
#
# ...

# %%
trd_kr_table =trd_kr_info.groupby(trd_kr_info['act_id']).mean()
trd_kr_table
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-50-b0716d601adc> in <module>
# ----> 1 trd_kr_table =trd_kr_info.groupby(trd_kr_info['act_id']).sum()
#       2 trd_kr_table
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in f(self, **kwargs)
#    1370                 # try a cython aggregation if we can
#    1371                 try:
# -> 1372                     return self._cython_agg_general(alias, alt=npfunc, **kwargs)
#    1373                 except DataError:
#    1374                     pass
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     991         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#     992     ) -> DataFrame:
# --> 993         agg_blocks, agg_items = self._cython_agg_blocks(
# ...

# %%
trd_oss_table = trd_oss_info.groupby('act_id').sum()
trd_oss_table
# Out:
#                                                         orr_dt  orr_ord  \
# act_id
# 000eb41ce4d0ad012c12b370642978ec645812e02266483...    40401246        3
# 00649c44a4f3149035ab8fa8b0df7c29f69ec70d77fbe9f...   787823667       78
# 006896b537767cd893f18f54ef8a60665592fc069e31391...   767620721      140
# 00e864e333fa507736d120dcfd770e216b914b31f8642b8...   202004845       15
# 00fb30f4b04caae456a222ead4da3a9f2ac31473bed69e8...   545411720       61
# ...                                                        ...      ...
# fef5ac5a6dfad3f344075353ffa43b45b7c7826a45c0680...  1231936200      129
# ff5c422b6b47267dc5b7585135a00da04c728fc32f75c07...   848419995       91
# ff607ee6d81379e30b6bed44db6ccd634f2d5e406f4ea1e...    60601831        4
# ff85c967c434b28730b755da5037159ce376f8766f20b1e...  1191824327      490
# ff86f59aa3c130c0f5f2c97e4d14fb6622455b1f61884c4...   101002171        7
#
#                                                     orr_rtn_hur  lst_cns_hur  \
# act_id
# ...

# %%
trade = pd.merge(trd_kr_table, trd_oss_table, on = 'act_id')

# %%
trade2 = pd.merge(act_info2, trade, on = 'act_id')

# %%
trade3 = pd.merge(customer_info, trade2, on = 'cus_id')
trade3
# Out:
#                                                 cus_id  sex_dit_cd  cus_age  \
# 0    2582f8ba6a49867ee265a2382d9a07cd4bee71d9e95c7a...           1       70
# 1    ef07ba51d74bd9643975549098f0ca37bafc93f9496528...           2       70
# 2    69c058f71b959ab4529f8b7d455d36bc7605a87cb95036...           2       70
# 3    5b4bd1d5fa738513eb1697b4687b0cc29e1eb275e2cbbf...           1       65
# 4    6cdc07565be85a63c4e2031d61fc34445e03b113e83642...           1       65
# ..                                                 ...         ...      ...
# 673  24653394d720670b49b1146b2793481bdca7aa7a84d11c...           1       55
# 674  35a141312260b8c75681c4523fe665b45c8ae85b82fe3b...           1       55
# 675  d7ec1ffebdbfa829cf7f4f982bcb90b29d112d34ea85aa...           1       40
# 676  7a75ef6ed9c903c6d18fa8f9eaf6767b06cbb434639652...           1       40
# 677  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
#
#     zip_ctp_cd tco_cus_grd_cd ivs_icn_cd  \
# ...

# %%
trade3.groupby("cus_age").mean()
# Out:
#          sex_dit_cd     act_opn_ym      orr_dt_x    orr_ord_x  orr_rtn_hur_x  \
# cus_age
# 0          1.363636  201877.681818  9.510701e+08   226.863636     539.409091
# 20         1.245614  201958.824561  2.415797e+09  1492.824561    1352.508772
# 25         1.298507  201885.917910  4.739757e+09  2377.223881    2562.947761
# 30         1.208696  201833.139130  4.504745e+09  2339.286957    2464.182609
# 35         1.298969  201732.010309  3.878993e+09  2654.927835    2086.051546
# 40         1.223684  201782.894737  3.373995e+09  1099.671053    1846.223684
# 45         1.302632  201586.723684  2.803779e+09  1057.381579    1540.223684
# 50         1.446809  201275.702128  8.791053e+09  7971.106383    5003.723404
# 55         1.312500  201514.968750  6.207031e+09  2282.437500    3321.875000
# 60         1.333333  201306.083333  9.273363e+08   207.333333     492.000000
# 65         1.000000  201145.200000  4.620905e+09   841.000000    2657.800000
# ...

# %%
Y_total = trade3[(trade3['cus_age']>=30) & (trade3['cus_age']<40)]
Z_total = trade3[(trade3['cus_age']>=20) & (trade3['cus_age']<30)]
Y_total
# Out:
#                                                 cus_id  sex_dit_cd  cus_age  \
# 41   4a6f40b737c84cad61932200e71830f779f497bb3caa68...           1       35
# 42   42d2b0e66f7dc238c251b3d188ad9edf7bc6b5a26def24...           1       35
# 43   c407bd4ff9fdf70c2f9072fb9f31e03d97821251786e25...           1       35
# 44   e6217d753c6b2a5462ecf0de303fc2b8ac077307e4a129...           2       35
# 45   3dc4d245daea373925bb9a7793748743c8db1b02d04be0...           1       35
# ..                                                 ...         ...      ...
# 665  4af3954a1fa406a844b71bfc132a684df6941aa559777c...           2       30
# 667  1583f8d921acc90c08a77453d342b6f80f218af64d7ff4...           1       30
# 668  d3845ff0d2e22d03030a78b2297d93f946b387e5d7f5f9...           1       30
# 670  b0c4d3d42788bf7af00431e34097d1feca666757567080...           1       30
# 677  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
#
#     zip_ctp_cd tco_cus_grd_cd ivs_icn_cd  \
# ...

# %%
Z_total
# Out:
#                                                 cus_id  sex_dit_cd  cus_age  \
# 50   8fbdbe578d91cf5da779308f5532e670a019faf62b7d24...           1       25
# 51   2d7d5326e07d358eb4df48b0c9df649a77a9e5020795c6...           2       25
# 52   2b45b32e55bfaf3951d320f9643a0e0d64083c6036c77b...           2       25
# 84   495178c589485e507475c0b727154e7f7d67de035c6bb7...           1       25
# 98   4dc04a92ab9215eafea61ec5bdc4d0db2f93556851f3fd...           2       25
# ..                                                 ...         ...      ...
# 652  6786feef1441aadfda0290c133d48a807bde84d98af12c...           1       20
# 657  cda3769784515fe29fdeeb68dbdef270b4e85b30ff459e...           1       20
# 660  259ed54b5a42880098bcbda7393e96649b0aa25a6a56b3...           1       20
# 664  8a40327805772cdc60a96ea8e0c80f3ad2109c9d4908f2...           2       25
# 666  6066de8a47f7fc0e2209b9f8e00a75fe31fa2cfec73c43...           2       25
#
#     zip_ctp_cd tco_cus_grd_cd ivs_icn_cd  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-649cfa3614a5> in <module>
# ----> 1 Y_total = pd.merge(Y_total, iem_info, on = 'iem_cd')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ...

# %%
Z_total.sort_values("tco_cus_grd_cd",ascending = False)
# Out:
#                                                 cus_id  sex_dit_cd  cus_age  \
# 666  6066de8a47f7fc0e2209b9f8e00a75fe31fa2cfec73c43...           2       25
# 642  5067921e6c5f4970cd5992c86c0356fac9ec4c2448d84c...           2       25
# 636  6c2cb57501c0b8b6e18e400150fbf47a62860ee5e1382c...           1       25
# 633  7d8b1a31bcba21f1db4fc3e06e10dd42e66324e3af50ac...           1       25
# 625  eb81a59ae704d08a1af905c962526e224f7545751284e2...           1       20
# ..                                                 ...         ...      ...
# 445  7f546522ee0627f7ffd7d9abe636a2eddd0ef2777307c3...           1       25
# 449  d6fd4427fda40fe44a213286d6ec58e8b42fa1c0d990cf...           1       25
# 170  11735ef7326573c9eecce4a4417cdec00964a86efdcb2d...           2       25
# 386  482bd0b267d15132da1aa8d7d6051fb11012d14b79e025...           1       25
# 414  374d04914e350b14d4a0a73ca0c8aad4d86eae439800ce...           1       25
#
#     zip_ctp_cd tco_cus_grd_cd ivs_icn_cd  \
# ...

# %%
df = Z_total.groupby('tco_cus_grd_cd').cus_age.count()
df.plot.bar()

# %%
df = Y_total.groupby('tco_cus_grd_cd').cus_age.count()
df.plot.bar()

# %% [raw]
# 01: 탑클래스 (자산1)10억이상 or 수익기여도2) 5백만원 이상)
# 02: 골드 (자산3억이상 or 수익기여도 3백만원 이상)
# 03: 로얄 (자산1억이상 or 수익기여도 1백만원 이상)
# 04: 그린 (자산3천이상 or 수익기여도 5십만원 이상)
# 05: 블루 (자산1천이상 or 수익기여도 1십만원 이상)
# 09: 등급 없음
# _: 해당 사항 없음

# %%
 Z_total.groupby('tco_cus_grd_cd').cns_qty_x.mean()
# Out:
# tco_cus_grd_cd
# 02      2943.250000
# 03    250028.272727
# 04    100928.083333
# 05     34126.648148
# 09      7661.445946
# _       2981.875000
# Name: cns_qty_x, dtype: float64

# %%
Z_total.groupby('tco_cus_grd_cd').cns_qty_y.mean()
# Out:
# tco_cus_grd_cd
# 02     1635.500000
# 03    10787.363636
# 04    16917.541667
# 05     2065.444444
# 09      653.067568
# _       101.541667
# Name: cns_qty_y, dtype: float64

# %%
Y_total.groupby('tco_cus_grd_cd').cns_qty_x.mean()
# Out:
# tco_cus_grd_cd
# 01    548624.000000
# 02    206556.444444
# 03    101401.593750
# 04     50806.673077
# 05     32367.343750
# 09     10021.255814
# _        211.545455
# Name: cns_qty_x, dtype: float64

# %%
Y_total.groupby('tco_cus_grd_cd').cns_qty_y.mean()
# Out:
# tco_cus_grd_cd
# 01       12.000000
# 02     7580.111111
# 03    13321.343750
# 04      983.634615
# 05     1425.593750
# 09      304.162791
# _        14.181818
# Name: cns_qty_y, dtype: float64

# %%
df = Z_total.groupby('ivs_icn_cd').cus_age.count()
df.plot.bar()

# %%
Y_total.groupby('ivs_icn_cd').cus_age.count()
df.plot.bar()

# %%
Z_total.groupby('ivs_icn_cd').cns_qty_x.mean()
# Out:
# ivs_icn_cd
# -       888.333333
# 01     2594.150000
# 02    21985.559322
# 03    52949.754717
# 04    73675.341463
# 05    32465.800000
# Name: cns_qty_x, dtype: float64

# %%
Z_total.groupby('ivs_icn_cd').cns_qty_y.mean()
# Out:
# ivs_icn_cd
# -     1050.333333
# 01    4217.350000
# 02     595.915254
# 03    7224.773585
# 04    4405.121951
# 05     489.466667
# Name: cns_qty_y, dtype: float64

# %%
Y_total.groupby('ivs_icn_cd').cns_qty_x.mean()
# Out:
# ivs_icn_cd
# -     214770.666667
# 00      3819.000000
# 01     16489.000000
# 02     22074.697674
# 03     33702.169492
# 04     61932.539683
# 05     78456.452381
# Name: cns_qty_x, dtype: float64

# %%
Y_total.groupby('ivs_icn_cd').cns_qty_y.mean()
# Out:
# ivs_icn_cd
# -     1428.000000
# 00       3.000000
# 01     152.000000
# 02    1567.837209
# 03    2728.423729
# 04    5500.555556
# 05    1685.000000
# Name: cns_qty_y, dtype: float64

# %%
trd_oss_table2 = trd_oss_info.groupby('act_id').count()

# %%
trd_kr_table2 = trd_kr_info.groupby('act_id').count()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-80-9a72d1ed1337> in <module>
# ----> 1 trd_kr_table2 = trd_kr_info.groupby('act_id').count()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in count(self)
#    1772             Count of values within each group.
#    1773         """
# -> 1774         data = self._get_data_to_aggregate()
#    1775         ids, _, ngroups = self.grouper.group_info
#    1776         mask = ids != -1
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _get_data_to_aggregate(self)
#    1647
#    1648     def _get_data_to_aggregate(self) -> BlockManager:
# -> 1649         obj = self._obj_with_exclusions
#    1650         if self.axis == 1:
#    1651             return obj.T._data
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ...

# %%
trade4 = pd.merge(trd_kr_table2, trd_oss_table2, on = 'act_id')
trade5 = pd.merge(, trd_oss_table, on = 'act_id')

# %%
df = pd.merge(cus_info, act_info2, on = "cus_id").dropna(subset =['sex_dit_cd'])

# %%
df = pd.merge(df, trd_oss_info, on = "act_id")

# %%
df = pd.merge(df, trd_kr_info, on = "act_id")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-9-5dfb048f99e6> in <module>
# ----> 1 df = pd.merge(df, trd_kr_info, on = "act_id")
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     653         rindexers = {1: right_indexer} if right_indexer is not None else {}
#     654
# --> 655         result_data = concatenate_block_managers(
#     656             [(ldata, lindexers), (rdata, rindexers)],
#     657             axes=[llabels.append(rlabels), join_index],
#
# ...

# %%
df
# Out:
#                                                   cus_id  sex_dit_cd  cus_age  \
# 0      2582f8ba6a49867ee265a2382d9a07cd4bee71d9e95c7a...           1       70
# 1      ef07ba51d74bd9643975549098f0ca37bafc93f9496528...           2       70
# 2      ef07ba51d74bd9643975549098f0ca37bafc93f9496528...           2       70
# 3      ef07ba51d74bd9643975549098f0ca37bafc93f9496528...           2       70
# 4      ef07ba51d74bd9643975549098f0ca37bafc93f9496528...           2       70
# ...                                                  ...         ...      ...
# 29296  7a75ef6ed9c903c6d18fa8f9eaf6767b06cbb434639652...           1       40
# 29297  7a75ef6ed9c903c6d18fa8f9eaf6767b06cbb434639652...           1       40
# 29298  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
# 29299  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
# 29300  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
#
# ...

# %%
Y= df[(df['cus_age']>=30) & (df['cus_age']<40)]
Z =df[(df['cus_age']>=20) & (df['cus_age']<30)]

# %%
Y
# Out:
#                                                   cus_id  sex_dit_cd  cus_age  \
# 2022   4a6f40b737c84cad61932200e71830f779f497bb3caa68...           1       35
# 2023   4a6f40b737c84cad61932200e71830f779f497bb3caa68...           1       35
# 2024   4a6f40b737c84cad61932200e71830f779f497bb3caa68...           1       35
# 2025   4a6f40b737c84cad61932200e71830f779f497bb3caa68...           1       35
# 2026   42d2b0e66f7dc238c251b3d188ad9edf7bc6b5a26def24...           1       35
# ...                                                  ...         ...      ...
# 29024  b0c4d3d42788bf7af00431e34097d1feca666757567080...           1       30
# 29025  b0c4d3d42788bf7af00431e34097d1feca666757567080...           1       30
# 29298  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
# 29299  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
# 29300  214df7b2a183c8c11b57289537897b7b456d38a222a5ef...           2       35
#
# ...

# %%
Z
# Out:
#                                                   cus_id  sex_dit_cd  cus_age  \
# 2148   8fbdbe578d91cf5da779308f5532e670a019faf62b7d24...           1       25
# 2149   8fbdbe578d91cf5da779308f5532e670a019faf62b7d24...           1       25
# 2150   8fbdbe578d91cf5da779308f5532e670a019faf62b7d24...           1       25
# 2151   8fbdbe578d91cf5da779308f5532e670a019faf62b7d24...           1       25
# 2152   8fbdbe578d91cf5da779308f5532e670a019faf62b7d24...           1       25
# ...                                                  ...         ...      ...
# 28832  7b7e7eabfa3afee8fe3a98a5b35cd99ef16b4b2818d2ce...           2       25
# 28833  7b7e7eabfa3afee8fe3a98a5b35cd99ef16b4b2818d2ce...           2       25
# 28834  7b7e7eabfa3afee8fe3a98a5b35cd99ef16b4b2818d2ce...           2       25
# 28849  6066de8a47f7fc0e2209b9f8e00a75fe31fa2cfec73c43...           2       25
# 28850  6066de8a47f7fc0e2209b9f8e00a75fe31fa2cfec73c43...           2       25
#
# ...

# %%
Y.groupby('cur_cd').cns_qty.mean()
# Out:
# cur_cd
# AUD     511.500000
# CAD     766.500000
# CNY     521.951220
# EUR       1.000000
# GBP    7800.233333
# HKD    6000.000000
# IDR    8200.000000
# JPY     292.857143
# USD      60.729034
# VND    1609.090909
# Name: cns_qty, dtype: float64

# %%
Z.groupby('cur_cd').cns_qty.mean()
# Out:
# cur_cd
# AUD       1.000000
# CAD     469.333333
# CNY     178.571429
# EUR       5.000000
# GBP     719.000000
# HKD    1963.636364
# JPY     281.450000
# USD      97.282013
# VND     178.000000
# Name: cns_qty, dtype: float64

# %%
Y.groupby('sby_dit_cd').cns_qty.mean()
# Out:
# sby_dit_cd
# 1    240.51710
# 2     77.67692
# Name: cns_qty, dtype: float64

# %%
Z.groupby('sby_dit_cd').cns_qty.mean()
# Out:
# sby_dit_cd
# 1    149.227535
# 2     78.236967
# Name: cns_qty, dtype: float64

# %%
Y.groupby('tco_cus_grd_cd').cns_qty.mean()
# Out:
# tco_cus_grd_cd
# 01      4.000000
# 02     61.548704
# 03    239.557427
# 04     46.609206
# 05     53.151498
# 09     25.123306
# _      35.393939
# Name: cns_qty, dtype: float64

# %%
Z.groupby('tco_cus_grd_cd').cns_qty.mean()
# Out:
# tco_cus_grd_cd
# 02    163.610687
# 03     91.286855
# 04    230.472208
# 05     40.094988
# 09     50.606960
# _      15.814978
# Name: cns_qty, dtype: float64

# %%
Y.groupby(['ivs_icn_cd','tco_cus_grd_cd']).count()
# Out:
#                            cus_id  sex_dit_cd  cus_age  zip_ctp_cd  act_id  \
# ivs_icn_cd tco_cus_grd_cd
# -          02                   1           1        1           1       1
#            04                   1           1        1           1       1
#            09                   6           6        6           6       6
# 00         04                   3           3        3           3       3
# 01         04                   9           9        9           9       9
# 02         03                  97          97       97          97      97
#            04                 100         100      100         100     100
#            05                 175         175      175         175     175
#            09                 129         129      129         129     129
#            _                   29          29       29          29      29
# 03         02                  25          25       25          25      25
# ...

# %%
Z.groupby(['ivs_icn_cd','tco_cus_grd_cd']).count()
# Out:
#                            cus_id  sex_dit_cd  cus_age  zip_ctp_cd  act_id  \
# ivs_icn_cd tco_cus_grd_cd
# -          02                   6           6        6           6       6
#            03                  17          17       17          17      17
#            09                   1           1        1           1       1
# 01         04                  80          80       80          80      80
#            05                 138         138      138         138     138
#            09                 105         105      105         105     105
#            _                   12          12       12          12      12
# 02         03                 765         765      765         765     765
#            04                  99          99       99          99      99
#            05                 801         801      801         801     801
#            09                 237         237      237         237     237
# ...

# %%
Z.groupby('orr_mdi_dit_cd').count()
# Out:
#                 cus_id  sex_dit_cd  cus_age  zip_ctp_cd  tco_cus_grd_cd  \
# orr_mdi_dit_cd
# 1                  118         118      118         118             118
# 3                 7324        7324     7324        7324            7324
# 4                   48          48       48          48              48
#
#                 ivs_icn_cd  act_id  act_opn_ym  orr_dt  orr_ord  orr_rtn_hur  \
# orr_mdi_dit_cd
# 1                      118     118         118     118      118          118
# 3                     7324    7324        7324    7324     7324         7324
# 4                       48      48          48      48       48           48
#
#                 lst_cns_hur  iem_cd  sby_dit_cd  cns_qty  orr_pr  cur_cd  \
# orr_mdi_dit_cd
# 1                       118     118         118      118     118     118
# 3                      7324    7324        7324     7324    7324    7324
# 4                        48      48          48       48      48      48
#
# ...

# %%
Y.groupby('orr_mdi_dit_cd').count()
# Out:
#                 cus_id  sex_dit_cd  cus_age  zip_ctp_cd  tco_cus_grd_cd  \
# orr_mdi_dit_cd
# 1                   18          18       18          18              18
# 3                 6853        6853     6853        6853            6853
# 4                  215         215      215         215             215
#
#                 ivs_icn_cd  act_id  act_opn_ym  orr_dt  orr_ord  orr_rtn_hur  \
# orr_mdi_dit_cd
# 1                       18      18          18      18       18           18
# 3                     6853    6853        6853    6853     6853         6853
# 4                      215     215         215     215      215          215
#
#                 lst_cns_hur  iem_cd  sby_dit_cd  cns_qty  orr_pr  cur_cd  \
# orr_mdi_dit_cd
# 1                        18      18          18       18      18      18
# 3                      6853    6853        6853     6853    6853    6853
# 4                       215     215         215      215     215     215
#
# ...

# %% [raw]
# HTS: 홈트레이딩 시스템- 투자자가 주식을 사고팔기 위해 증권사 객장에 나가거나 전화를 거는 대신 집이나 사무실에 설치된 PC를 통해 거래할 수 있는 시스템을 말한다. 매매수수료가 저렴하고 어디서나 인터넷만 연결되면 거래가 가능하다는 편리함이 있다.
#
# MTS: 모바일 거래 시스템 - 스마트폰 등의 이동통신 기기를 사용한 거래 시스템
